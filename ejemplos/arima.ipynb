# %% [markdown]
# ![](https://mcd.unison.mx/wp-content/themes/awaken/img/logo_mcd.png)
#
# # Modelos ARIMA
#
# ## Aprendizaje Automático Aplicado
#
# **Julio Waissman**
#
# Mayo, 2024

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm

air_url = "https://raw.githubusercontent.com/selva86/datasets/master/AirPassengers.csv"
air_df = pd.read_csv(air_url)
air_df['date'] = pd.to_datetime(air_df['date'])
air_df.set_index('date', inplace=True)

# %%
air_df.plot(figsize=(12, 6))
# Out:
# <Axes: xlabel='date'>
